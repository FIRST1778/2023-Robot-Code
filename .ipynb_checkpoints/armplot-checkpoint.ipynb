# %%
import csv

with open("logs.csv") as f:
    r = csv.reader(f)
    rows = [row for row in r]

from matplotlib import pyplot as plt
def plot_positions(ts, xs, label):
    plt.xlabel("time (s)")
    plt.plot(ts, xs)
    plt.ylabel(label)
    plt.show()

# time, velocity at joint (rad/s), angle at joint (deg), voltage, current, Ks
rows = rows[1:50]  # remove header and incomplete last line
times = [float(row[0]) for row in rows] 
labels = ["velocity at joint (rad/s)", "angle at joint (deg)", "voltage", "current", "Ks"]

for i, v in enumerate(labels):
    plot_positions(times, [float(row[i+1]) for row in rows], v)
